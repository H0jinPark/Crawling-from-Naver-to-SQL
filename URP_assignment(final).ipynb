# %% [markdown]
# # 2024-2 URP assignment

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urlparse, parse_qs
import re
import pandas as pd
from datetime import datetime
from tqdm import tqdm
import time

# %%
# 데이터프레임 선언
Q_df = pd.DataFrame(columns = ['문서 번호', '제목',  '질문',  "위치 고유번호" , '조회수', '질문 날짜'])
A_df = pd.DataFrame(columns = ['문서 번호', '답변 ID',  '답변', '답변 날짜'])
loc_dict = pd.read_csv("naver_kin_regions_df_l2.csv", index_col = "지역 코드")

# %% [markdown]
# # URL에서 dirID 값을 가져오는 함수

# %%
def get_dirid(url):
    match = re.search(r'dirId=12(\d+)', url)
    dirid_value = match.group(1)
    return dirid_value

# %% [markdown]
# # URL에서 docID 값을 가져오는 함수

# %%
def get_docid(url):
    match = re.search(r'docId=(\d+)', url)
    dirid_value = match.group(1)
    return dirid_value

# %% [markdown]
# # 반복되는 패턴을 통해서 docID를 통해 위치 반환하는 함수(추후 매핑 테이블을 이용할 예정)

# %%
# dirID -> loc
def get_loc(id=""):
    url = 'https://kin.naver.com/qna/list.naver?dirId=12'+id

    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    response = requests.get(url, headers=headers)

    soup = BeautifulSoup(response.text, 'html.parser')

    location = soup.find(attrs={'class': 'location'}).get_text(strip=True)
    return location

# %%
def find_pattern(text):
    # 문자열 길이의 절반까지 탐색(더 긴 패턴은 두 번 반복될 수 없으므로)
    for length in range(1, len(text)):
        # 길이 `length`만큼 패턴을 잘라서 비교
        pattern = text[:length]
        # 패턴이 두 번 연속 반복되는지 확인
        if text.startswith(pattern * 2):
            return pattern

# %%
# 지역 & 플레이스 기본 정보 문자열 제거를 위한 변수 지정
url2 = 'https://kin.naver.com/qna/list.naver?dirId=12'
headers2 = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}
response2 = requests.get(url2, headers=headers2)
soup2 = BeautifulSoup(response2.text, 'html.parser')
useless_information = soup2.find(attrs={'class': 'location'}).get_text(strip=True)

def return_location(search):
    a = get_loc(search[:-2]+"01").replace(get_loc(search[:-2]),"")
    a_elim = get_loc(search[:-len(search)]+search[-len(search):-2]).replace(get_loc(search[:-len(search)]),"")
    first_loc = find_pattern(a)
    a = a[len(first_loc):]
    b = get_loc(search).replace(a,"")
    c = b.replace(useless_information, "")
    return c.replace(a_elim,"")

def return_full_location(search):
    full_location = ""
    n = 2
    while n <= len(search):
        full_location += return_location(search[:n])+ " "
        n += 2
    return full_location

# %% [markdown]
# # 최종적으로 질문과 답변 정보 받아오는 함수

# %%
def collect_information(url, Q_df, A_df):
    # 페이지 요청
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
    }
    response = requests.get(url, headers=headers)

    # BeautifulSoup으로 페이지 파싱
    soup = BeautifulSoup(response.text, 'html.parser')

    # 질문 제목 추출
    title = soup.find(attrs={'class': 'endTitleSection'}).get_text(strip=True)
    title = title.replace(",","")
    Q_detail= soup.find(attrs={'class': 'questionDetail'}).get_text(strip=True,separator=' ')
    Q_detail = Q_detail.replace(",","")
    Q_info = soup.find_all(class_='infoItem')
    Q_view = Q_info[0].get_text()[3:]
    Q_date = Q_info[1].get_text()[3:]
    if Q_date.endswith(" 전"):
        Q_date = datetime.today().strftime('%Y.%m.%d')
    if Q_date.startswith("작성일"):
        Q_date = Q_date.replace("작성일", "")
    ans = []
    A_dates = []
    try:
        answers = soup.find_all(class_='se-main-container')
        ans_date = soup.find_all(class_='answerDate')
        for answer in answers:
            ans.append(answer.get_text(strip=True).replace('\u200b', ''))
        for ans_dates in ans_date:
            A_dates.append(ans_dates.get_text(strip=True))
    except:
        answer_error = "아직 답변이 없습니다"
    
    ID = get_dirid(url)
    doc_ID = get_docid(url)
    Q_inf_list =[get_docid(url), title, Q_detail, ID, Q_view, Q_date]
    A_inf_list =[]
    n = 1
    for i,j in zip(ans,A_dates):
        changed = i.replace(","," ")
        if j.endswith(" 전"):
            today = datetime.today().strftime('%Y.%m.%d.')
            A_inf_list.append([doc_ID, doc_ID+str(n), changed[2:],today])
        else:
            A_inf_list.append([doc_ID, doc_ID+str(n), changed[2:],j])
        n += 1
    Q_df.loc[Q_df.shape[0]] = Q_inf_list
    
    for i in A_inf_list:
        A_df.loc[A_df.shape[0]] = i
    return Q_df, A_df

# %% [markdown]
# # 질문 리스트에서 각 질문의 URL 값 가져오기

# %%
# 질문 목록에서 URL만 가져기기
urls = []
def get_url_from_list(search_url):
    global urls
    response = requests.get(search_url) 
    
    soup = BeautifulSoup(response.text, 'html.parser')

    elements = soup.find_all(class_=re.compile(r'^_nclicks:kls_new\.list'))
    
    for element in elements[1:]:
        href = "https://kin.naver.com"+element.get('href')
        urls.append(href)
    return urls

# %% [markdown]
# ### list 페이지 설정

# %%
for i in range(1,11):
    page = f"https://kin.naver.com/qna/list.naver?dirId=1201&queryTime={datetime.today().strftime('%Y-%m-%d')}%2000%3A25%3A07&page={i}"
    urls = get_url_from_list(page)

# %%
urls
# Out:
# ['https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12012902&docId=476675172',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12012106&docId=476735663',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476733787',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120110&docId=476731997',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476731975',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476731834',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476731599',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12012404&docId=476731547',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12013211&docId=476730994',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120132&docId=476636453',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476730686',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476729776',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476729758',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120101&docId=476729628',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476728750',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476728543',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120134&docId=476727598',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476727444',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12012902&docId=476726163',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476725533',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12013301&docId=476703045',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120110&docId=476702990',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120130&docId=476701414',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12013401&docId=476700493',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12012707&docId=476699778',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12013211&docId=476699320',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120110&docId=476697850',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120121&docId=476696609',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476695489',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12012605&docId=476694750',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12013757&docId=476694403',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120134&docId=476694046',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12013757&docId=476560958',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120101&docId=476562836',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476692576',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120115&docId=476692360',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476692022',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120118&docId=476521473',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120135&docId=476691461',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12011703&docId=476690288',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12011604&docId=476689485',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120131&docId=476688600',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120101&docId=476687844',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120121&docId=476687580',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476685629',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12013404&docId=476576704',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120132&docId=476685111',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12013749&docId=476684630',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12011510&docId=476683768',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12012508&docId=476682304',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476681717',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476681214',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476680147',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120111&docId=476562398',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120117&docId=476680005',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476678908',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120116&docId=476610313',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120138&docId=476676978',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12011505&docId=476675226',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476674789',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12012711&docId=476673306',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120110&docId=476546160',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476672789',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12012707&docId=476672555',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476671954',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120136&docId=476671446',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12012501&docId=476670782',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120115&docId=476670631',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12013211&docId=476669734',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476668972',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12012601&docId=476668893',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12012803&docId=476668126',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476667611',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476667136',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476667021',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120115&docId=476665885',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120115&docId=476665168',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12013112&docId=476664086',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=120101&docId=476662021',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=1201&docId=476612548',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12013752&docId=476660224',
#  'https://kin.naver.com/qna/detail.naver?d1id=12&dirId=12
# 198  476594936                       질문종로 야장...
# 199  476594272  질문중학생끼리 국내에서 재밌게 놀수 있는 지역 있을까요?
#
#                                                     질문 위치 고유번호  조회수  \
# 0    성심여고 재학생 중 어셔어학원 다녔다는 후기가 있던데 토플학원이라고 나와있더라고요....  012902   13
# 1                                    신도림 고등학교 가기 어렵나요?  012106   10
# 2    노랑버스 빨강버스 2대 있는거같은데 각각 노선이 조금 다른거 같더라구요 주간운행 야...      01   11
# 3    부산에서 남고딩 4명 아이콘 매치 보러 1920일날 올라갑니다. 모텔 홍대쪽에 잡았...    0110   14
# 4    엄마가 대학 전문학교는 안쳐준다면서 취업할때 그래서 조대이공대가서 하라하는데 어디로...      01   11
# ..                                                 ...     ...  ...
# 195  제가 지금 여고를 다니고 있는데 걍 꼴지입니다 공부도 못하고 공부하는 법을 아직도 ...      01   32
# 196  저와 제 남자친구는 130일 쯤 됐어요. 오랜만난 사이는 아니에요. 저희는 장거리연...      01   20
# 197                       신월동에서 바자회 한다고 하던데 아시는분 있을까요?  013302   18
# 198   종로 야장 기간이 언제까진가요!?? 여름에만 여나요??아님 몇월달까지 하는지 알려주세여  013757   23
# 199  안녕하세요 전 중3이구요 제가 4년동안 알고지내던 온라인 친구들끼리 이번에 만나자해...      01   33
#
#           질문 날짜
# 0    2024.10.17
# 1    2024.10.17
# 2    2024.10.17
# 3    2024.10.17
# 4    2024.10.17
# ..          ...
# 195  2024.10.14
# 196  2024.10.14
# 197  2024.10.14
# 198  2024.10.14
# 199  2024.10.14
#
# [200 rows x 6 columns]

# %%
A_df
# Out:
#          문서 번호       답변 ID                                                 답변  \
# 0    476733787  4767337871        가능하고 1시간정도만 있어도 이동가능합니다.서울 땅덩어리가 그리 크지않습니다.
# 1    476731997  4767319971   추천지  입니다1.장소 입니다방탈출카페  공포.미스터리. 스릴러보드게임카페애견카페...
# 2    476731975  4767319751                                          이공대 추천합니다
# 3    476731834  4767318341   고구려목장위치: 경기도 양주설명: 고구려목장은 넓은 부지에 젖소와 양떼를 볼 수 ...
# 4    476731834  4767318342   농장도 괜찮은데...멀수도 있어서요~차라리 서울맘카페에 아이랑 동물 볼수 있는곳으...
# ..         ...         ...                                                ...
# 227  476594936  4765949361                                           월말까지 합니다
# 228  476594936  4765949362  월 ~ 11월 중반까지는 활발한 영업 시기이고11월 중반이후 부터  비닐쒸우고 밖에...
# 229  476594272  4765942721   친구 가족단위로 갈 수 있는 아주 재미있는 축제를 알아보던 중 대구 이월드 펌킨 ...
# 230  476594272  4765942722                                             랜드 레츠고
# 231  476594272  4765942723  게 놀려면은 그래도 테마파크가 있어야 하는데규모가 있는 테마파크가 있는 곳이라면은경...
#
#            답변 날짜
# 0    2024.10.17.
# 1    2024.10.17.
# 2    2024.10.17.
# 3    2024.10.17.
# 4    2024.10.17.
# ..           ...
# 227  2024.10.14.
# 228  2024.10.14.
# 229  2024.10.15.
# 230  2024.10.14.
# 231  2024.10.14.
#
# [232 rows x 4 columns]

# %%
Q_df.to_csv('Questions.csv', index = False)
A_df.to_csv('Answers.csv', index = False)
